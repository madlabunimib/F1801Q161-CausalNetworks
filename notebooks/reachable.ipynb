# %%
# %%capture
# !pip install networkx

# %%
import networkx as nx

from enum import Enum
from itertools import chain, combinations
from typing import Set

# %% [markdown]
# # An Implementation of the Reachable Algorithm

# %% [markdown]
# By Alessio Zanga and Fabio Stella

# %% [markdown]
# ## Implementation

# %% [markdown]
# Define an enumerator from UP/DOWN constants:

# %%
class Direction(Enum):
    DOWN = 0
    UP = 1

# %% [markdown]
# Implement the $Reachable$ algorithm:

# %%
def reachable(G: nx.DiGraph, X: str, Z: Set[str]) -> Set[str]:
    # Phase I: Insert all ancestors of Z into A.

    # Ancestral set of Z.
    A = set()
    # To-be-visited nodes set.
    L = Z.copy()
    # While there are still nodes to be visited.
    while L:
        # Select a node to be visited.
        Y = L.pop()
        # If it is not in the ancestral set.
        if Y not in A:
            # Add its parents to the nodes to be visited.
            L |= set(G.predecessors(Y))
            # Add it to ancestral set.
            A |= { Y }
    
    # Phase II: Traverse active trails starting from X.

    # Reachable nodes set.
    R = set()
    # Already-visited nodes set.
    V = set()
    # To-be-visited nodes set.
    L = { (X, Direction.UP) }
    # While there are still nodes to be visited.
    while L:
        # Select a node to be visited.
        (Y, d) = L.pop()
        # Check if already visited.
        if (Y, d) not in V:
            # If not in the conditioning set.
            if Y not in Z:
                # Then, it is reachable.
                R |= { Y }
            # Set (Y, d) as visisted.
            V |= { (Y, d) }
            # Trail up.
            if d == Direction.UP and Y not in Z:
                # For each parent of Y, visit from bottom.
                L |= { (W, Direction.UP) for W in G.predecessors(Y)}
                # For each child of Y, visit from top.
                L |= { (W, Direction.DOWN) for W in G.successors(Y) }
            # Trail down.
            elif d == Direction.DOWN:
                if Y not in Z:
                    # For each child of Y, visit from top.
                    L |= { (W, Direction.DOWN) for W in G.successors(Y) }
                if Y in A:
                    # For each parent of Y, visit from bottom.
                    L |= { (W, Direction.UP) for W in G.predecessors(Y)}
    
    # Return the reachable nodes.
    return R

# %% [markdown]
# Define a DAG $\mathcal{G}$:

# %%
G = nx.DiGraph([("A", "C"), ("B", "C"), ("C", "D"), ("A", "E"), ("B", "F")])

# %% [markdown]
# Define the powerset $2^{\mathbf{S}}$ of a set $\mathbf{S}$:

# %%
def powerset(S: Set[str]):
    return map(set, chain.from_iterable(
        combinations(S, k)
        for k in range(len(S) + 1)
    ))

list(powerset(["A", "B", "C"]))
# Out:
# [set(),
#  {'A'},
#  {'B'},
#  {'C'},
#  {'A', 'B'},
#  {'A', 'C'},
#  {'B', 'C'},
#  {'A', 'B', 'C'}]

# %% [markdown]
# Test this $Reachable$ implementation for each possible combination of nodes given $\mathcal{G}$ using d-separation:

# %%
# Get the vertex set V.
V = set(G.nodes)
# For each X node in V.
for X in V:
    # For each node in 2^(V \ {X})
    for Z in powerset(V - { X }):
        # Get the reachable nodes from X given Z.
        R = reachable(G, X, Z)
        # For each node Y which is not X and not in Z.
        for Y in  V - { X } - Z:
            # Check if it is reachable and d-separated.
            is_reachable = (Y in R)
            is_d_separated = nx.is_d_separator(G, { X }, { Y }, Z)
            # If it is reachable then it is not d-separated, and vice-versa.
            assert is_reachable == (not is_d_separated)
            # Log the execution.
            print(f"Is '{Y}' reachable from '{X}' given '{Z}'? {is_reachable}")
            print(f"Is '{Y}' d-separated from '{X}' given '{Z}'? {is_d_separated}\n")
# Out:
# Is 'A' reachable from 'D' given 'set()'? True
# Is 'A' d-separated from 'D' given 'set()'? False
#
# Is 'E' reachable from 'D' given 'set()'? True
# Is 'E' d-separated from 'D' given 'set()'? False
#
# Is 'B' reachable from 'D' given 'set()'? True
# Is 'B' d-separated from 'D' given 'set()'? False
#
# Is 'F' reachable from 'D' given 'set()'? True
# Is 'F' d-separated from 'D' given 'set()'? False
#
# Is 'C' reachable from 'D' given 'set()'? True
# Is 'C' d-separated from 'D' given 'set()'? False
#
# Is 'F' reachable from 'D' given '{'A'}'? True
# Is 'F' d-separated from 'D' given '{'A'}'? False
#
# Is 'C' reachable from 'D' given '{'A'}'? True
# Is 'C' d-separated from 'D' given '{'A'}'? False
#
# Is 'E' reachable from 'D' given '{'A'}'? False
# Is 'E' d-separated from 'D' given '{'A'}'? True
#
# Is 'B' reachable from 'D' given '{'A'}'? True
# Is 'B' d-separated from 'D' given '{'A'}'? False
#
# Is 'F' reachable from 'D' given '{'E'}'? True
# Is 'F' d-separated from 'D' given '{'E'}'? False
#
# Is 'A' reachable from 'D' given '{'E'}'? True
# Is 'A' d-separated from 'D' given '{'E'}'? False
#
# Is 'C' reachable from 'D' given '{'E'}'? True
# Is 'C' d-separated from 'D' given '{'E'}'? False
#
# Is 'B' reachable from 'D' given '{'E'}'? True
# Is 'B' d-separated from 'D' given '{'E'}'? False
#
# Is 'A' reachable from 'D' given '{'F'}'? True
# Is 'A' d-separated from 'D' given '{'F'}'? False
#
# Is 'C' reachable from 'D' given '{'F'}'? True
# Is 'C' d-separated from 'D' given '{'F'}'? False
#
# Is 'E' reachable from 'D' given '{'F'}'? True
# Is 'E' d-separated from 'D' given '{'F'}'? False
#
# Is 'B' reachable from 'D' given '{'F'}'? True
# Is 'B' d-separated from 'D' given '{'F'}'? False
#
# Is 'F' reachable from 'D' given '{'B'}'? False
# Is 'F' d-separated from 'D' given '{'B'}'? True
#
# Is 'A' reachable from 'D' given '{'B'}'? True
# Is 'A' d-separated from 'D' given '{'B'}'? False
#
# Is 'C' reachable from 'D' given '{'B'}'? True
# Is 'C' d-separated from 'D' given '{'B'}'? False
#
# Is 'E' reachable from 'D' given '{'B'}'? True
# Is 'E' d-separated from 'D' given '{'B'}'? False
#
# Is 'F' reachable from 'D' given '{'C'}'? False
# Is 'F' d-separated from 'D' given '{'C'}'? True
#
# Is 'A' reachable from 'D' given '{'C'}'? False
# Is 'A' d-separated from 'D' given '{'C'}'? True
#
# Is 'E' reachable from 'D' given '{'C'}'? False
# Is 'E' d-separated from 'D' given '{'C'}'? True
#
# Is 'B' reachable from 'D' given '{'C'}'? False
# Is 'B' d-separated from 'D' given '{'C'}'? True
#
# Is 'F' reachable from 'D' given '{'A', 'E'}'? True
# Is 'F' d-separated from 'D' given '{'A', 'E'}'? False
#
# Is 'C' reachable from 'D' given '{'A', 'E'}'? True
# Is 'C' d-separated from 'D' given '{'A', 'E'}'? False
#
# Is 'B' reachable from 'D' given '{'A', 'E'}'? True
# Is 'B' d-separated from 'D' given '{'A', 'E'}'? False
#
# Is 'C' reachable from 'D' given '{'F', 'A'}'? True
# Is 'C' d-separated from 'D' given '{'F', 'A'}'? False
#
# Is 'E' reachable from 'D' given '{'F', 'A'}'? False
# Is 'E' d-separated from 'D' given '{'F', 'A'}'? True
#
# Is 'B' reachable from 'D' given '{'F', 'A'}'? True
# Is 'B' d-separated from 'D' given '{'F', 'A'}'? False
#
# Is 'F' reachable from 'D' given '{'A', 'B'}'? False
# Is 'F' d-separated from 'D' given '{'A', 'B'}'? True
#
# Is 'C' reachable from 'D' given '{'A', 'B'}'? True
# Is 'C' d-separated from 'D' given '{'A', 'B'}'? False
#
# Is 'E' reachable from 'D' given '{'A', 'B'}'? False
# Is 'E' d-separated from 'D' given '{'A', 'B'}'? True
#
# Is 'F' reachable from 'D' given '{'A', 'C'}'? False
# Is 'F' d-separated from 'D' given '{'A', 'C'}'? True
#
# Is 'E' reachable from 'D' given '{'A', 'C'}'? False
# Is 'E' d-separated from 'D' given '{'A', 'C'}'? True
#
# Is 'B' reachable from 'D' given '{'A', 'C'}'? False
# Is 'B' d-separated from 'D' given '{'A', 'C'}'? True
#
# Is 'A' reachable from 'D' given '{'F', 'E'}'? True
# Is 'A' d-separated from 'D' given '{'F', 'E'}'? False
#
# Is 'C' reachable from 'D' given '{'F', 'E'}'? True
# Is 'C' d-separated from 'D' given '{'F', 'E'}'? False
#
# Is 'B' reachable from 'D' given '{'F', 'E'}'? True
# Is 'B' d-separated from 'D' given '{'F', 'E'}'? False
#
# Is 'F' reachable from 'D' given '{'E', 'B'}'? False
# Is 'F' d-separated from 'D' given '{'E', 'B'}'? True
#
# Is 'A' reachable from 'D' given '{'E', 'B'}'? True
# Is 'A' d-separated from 'D' given '{'E', 'B'}'? False
#
# Is 'C' reachable from 'D' given '{'E', 'B'}'? True
# Is 'C' d-separated from 'D' given '{'E', 'B'}'? False
#
# Is 'F' reachable from 'D' given '{'C', 'E'}'? False
# Is 'F' d-separated from 'D' given '{'C', 'E'}'? True
#
# Is 'A' reachable from 'D' given '{'C', 'E'}'? False
# Is 'A' d-separated from 'D' given '{'C', 'E'}'? True
#
# Is 'B' reachable from 'D' given '{'C', 'E'}'? False
# Is 'B' d-separated from 'D' given '{'C', 'E'}'? True
#
# Is 'A' reachable from 'D' given '{'F', 'B'}'? True
# Is 'A' d-separated from 'D' given '{'F', 'B'}'? False
#
# Is 'C' reachable from 'D' given '{'F', 'B'}'? True
# Is 'C' d-separated from 'D' given '{'F', 'B'}'? False
#
# Is 'E' reachable from 'D' given '{'F', 'B'}'? True
# Is 'E' d-separated from 'D' given '{'F', 'B'}'? False
#
# Is 'A' reachable from 'D' given '{'F', 'C'}'? False
# Is 'A' d-separated from 'D' given '{'F', 'C'}'? True
#
# Is 'E' reachable from 'D' given '{'F', 'C'}'? False
# Is 'E' d-separated from 'D' given '{'F', 'C'}'? True
#
# Is 'B' reachable from 'D' given '{'F', 'C'}'? False
# Is 'B' d-separated from 'D' given '{'F', 'C'}'? True
#
# Is 'F' reachable from 'D' given '{'C', 'B'}'? False
# Is 'F' d-separated from 'D' given '{'C', 'B'}'? True
#
# Is 'A' reachable from 'D' given '{'C', 'B'}'? False
# Is 'A' d-separated from 'D' given '{'C', 'B'}'? True
#
# Is 'E' reachable from 'D' given '{'C', 'B'}'? False
# Is 'E' d-separated from 'D' given '{'C', 'B'}'? True
#
# Is 'C' reachable from 'D' given '{'F', 'A', 'E'}'? True
# Is 'C' d-separated from 'D' given '{'F', 'A', 'E'}'? False
#
# Is 'B' reachable from 'D' given '{'F', 'A', 'E'}'? True
# Is 'B' d-separated from 'D' given '{'F', 'A', 'E'}'? False
#
# Is 'F' reachable from 'D' given '{'A', 'E', 'B'}'? False
# Is 'F' d-separated from 'D' given '{'A', 'E', 'B'}'? True
#
# Is 'C' reachable from 'D' given '{'A', 'E', 'B'}'? True
# Is 'C' d-separated from 'D' given '{'A', 'E', 'B'}'? False
#
# Is 'F' reachable from 'D' given '{'A', 'C', 'E'}'? False
# Is 'F' d-separated from 'D' given '{'A', 'C', 'E'}'? True
#
# Is 'B' reachable from 'D' given '{'A', 'C', 'E'}'? False
# Is 'B' d-separated from 'D' given '{'A', 'C', 'E'}'? True
#
# Is 'C' reachable from 'D' given '{'F', 'A', 'B'}'? True
# Is 'C' d-separated from 'D' given '{'F', 'A', 'B'}'? False
#
# Is 'E' reachable from 'D' given '{'F', 'A', 'B'}'? False
# Is 'E' d-separated from 'D' given '{'F', 'A', 'B'}'? True
#
# Is 'E' reachable from 'D' given '{'F', 'A', 'C'}'? False
# Is 'E' d-separated from 'D' given '{'F', 'A', 'C'}'? True
#
# Is 'B' reachable from 'D' given '{'F', 'A', 'C'}'? False
# Is 'B' d-separated from 'D' given '{'F', 'A', 'C'}'? True
#
# Is 'F' reachable from 'D' given '{'A', 'C', 'B'}'? False
# Is 'F' d-separated from 'D' given '{'A', 'C', 'B'}'? True
#
# Is 'E' reachable from 'D' given '{'A', 'C', 'B'}'? False
# Is 'E' d-separated from 'D' given '{'A', 'C', 'B'}'? True
#
# Is 'A' reachable from 'D' given '{'F', 'E', 'B'}'? True
# Is 'A' d-separated from 'D' given '{'F', 'E', 'B'}'? False
#
# Is 'C' reachable from 'D' given '{'F', 'E', 'B'}'? True
# Is 'C' d-separated from 'D' given '{'F', 'E', 'B'}'? False
#
# Is 'A' reachable from 'D' given '{'F', 'C', 'E'}'? False
# Is 'A' d-separated from 'D' given '{'F', 'C', 'E'}'? True
#
# Is 'B' reachable from 'D' given '{'F', 'C', 'E'}'? False
# Is 'B' d-separated from 'D' given '{'F', 'C', 'E'}'? True
#
# Is 'F' reachable from 'D' given '{'C', 'E', 'B'}'? False
# Is 'F' d-separated from 'D' given '{'C', 'E', 'B'}'? True
#
# Is 'A' reachable from 'D' given '{'C', 'E', 'B'}'? False
# Is 'A' d-separated from 'D' given '{'C', 'E', 'B'}'? True
#
# Is 'A' reachable from 'D' given '{'F', 'C', 'B'}'? False
# Is 'A' d-separated from 'D' given '{'F', 'C', 'B'}'? True
#
# Is 'E' reachable from 'D' given '{'F', 'C', 'B'}'? False
# Is 'E' d-separated from 'D' given '{'F', 'C', 'B'}'? True
#
# Is 'C' reachable from 'D' given '{'F', 'A', 'E', 'B'}'? True
# Is 'C' d-separated from 'D' given '{'F', 'A', 'E', 'B'}'? False
#
# Is 'B' reachable from 'D' given '{'F', 'A', 'C', 'E'}'? False
# Is 'B' d-separated from 'D' given '{'F', 'A', 'C', 'E'}'? True
#
# Is 'F' reachable from 'D' given '{'A', 'C', 'E', 'B'}'? False
# Is 'F' d-separated from 'D' given '{'A', 'C', 'E', 'B'}'? True
#
# Is 'E' reachable from 'D' given '{'F', 'A', 'C', 'B'}'? False
# Is 'E' d-separated from 'D' given '{'F', 'A', 'C', 'B'}'? True
#
# Is 'A' reachable from 'D' given '{'F', 'C', 'E', 'B'}'? False
# Is 'A' d-separated from 'D' given '{'F', 'C', 'E', 'B'}'? True
#
# Is 'D' reachable from 'A' given 'set()'? True
# Is 'D' d-separated from 'A' given 'set()'? False
#
# Is 'E' reachable from 'A' given 'set()'? True
# Is 'E' d-separated from 'A' given 'set()'? False
#
# Is 'B' reachable from 'A' given 'set()'? False
# Is 'B' d-separated from 'A' given 'set()'? True
#
# Is 'F' reachable from 'A' given 'set()'? False
# Is 'F' d-separated from 'A' given 'set()'? True
#
# Is 'C' reachable from 'A' given 'set()'? True
# Is 'C' d-separated from 'A' given 'set()'? False
#
# Is 'F' reachable from 'A' given '{'D'}'? True
# Is 'F' d-separated from 'A' given '{'D'}'? False
#
# Is 'C' reachable from 'A' given '{'D'}'? True
# Is 'C' d-separated from 'A' given '{'D'}'? False
#
# Is 'E' reachable from 'A' given '{'D'}'? True
# Is 'E' d-separated from 'A' given '{'D'}'? False
#
# Is 'B' reachable from 'A' given '{'D'}'? True
# Is 'B' d-separated from 'A' given '{'D'}'? False
#
# Is 'F' reachable from 'A' given '{'E'}'? False
# Is 'F' d-separated from 'A' given '{'E'}'? True
#
# Is 'D' reachable from 'A' given '{'E'}'? True
# Is 'D' d-separated from 'A' given '{'E'}'? False
#
# Is 'C' reachable from 'A' given '{'E'}'? True
# Is 'C' d-separated from 'A' given '{'E'}'? False
#
# Is 'B' reachable from 'A' given '{'E'}'? False
# Is 'B' d-separated from 'A' given '{'E'}'? True
#
# Is 'D' reachable from 'A' given '{'F'}'? True
# Is 'D' d-separated from 'A' given '{'F'}'? False
#
# Is 'C' reachable from 'A' given '{'F'}'? True
# Is 'C' d-separated from 'A' given '{'F'}'? False
#
# Is 'E' reachable from 'A' given '{'F'}'? True
# Is 'E' d-separated from 'A' given '{'F'}'? False
#
# Is 'B' reachable from 'A' given '{'F'}'? False
# Is 'B' d-separated from 'A' given '{'F'}'? True
#
# Is 'F' reachable from 'A' given '{'B'}'? False
# Is 'F' d-separated from 'A' given '{'B'}'? True
#
# Is 'D' reachable from 'A' given '{'B'}'? True
# Is 'D' d-separated from 'A' given '{'B'}'? False
#
# Is 'C' reachable from 'A' given '{'B'}'? True
# Is 'C' d-separated from 'A' given '{'B'}'? False
#
# Is 'E' reachable from 'A' given '{'B'}'? True
# Is 'E' d-separated from 'A' given '{'B'}'? False
#
# Is 'F' reachable from 'A' given '{'C'}'? True
# Is 'F' d-separated from 'A' given '{'C'}'? False
#
# Is 'D' reachable from 'A' given '{'C'}'? False
# Is 'D' d-separated from 'A' given '{'C'}'? True
#
# Is 'E' reachable from 'A' given '{'C'}'? True
# Is 'E' d-separated from 'A' given '{'C'}'? False
#
# Is 'B' reachable from 'A' given '{'C'}'? True
# Is 'B' d-separated from 'A' given '{'C'}'? False
#
# Is 'F' reachable from 'A' given '{'D', 'E'}'? True
# Is 'F' d-separated from 'A' given '{'D', 'E'}'? False
#
# Is 'C' reachable from 'A' given '{'D', 'E'}'? True
# Is 'C' d-separated from 'A' given '{'D', 'E'}'? False
#
# Is 'B' reachable from 'A' given '{'D', 'E'}'? True
# Is 'B' d-separated from 'A' given '{'D', 'E'}'? False
#
# Is 'C' reachable from 'A' given '{'F', 'D'}'? True
# Is 'C' d-separated from 'A' given '{'F', 'D'}'? False
#
# Is 'E' reachable from 'A' given '{'F', 'D'}'? True
# Is 'E' d-separated from 'A' given '{'F', 'D'}'? False
#
# Is 'B' reachable from 'A' given '{'F', 'D'}'? True
# Is 'B' d-separated from 'A' given '{'F', 'D'}'? False
#
# Is 'F' reachable from 'A' given '{'D', 'B'}'? False
# Is 'F' d-separated from 'A' given '{'D', 'B'}'? True
#
# Is 'C' reachable from 'A' given '{'D', 'B'}'? True
# Is 'C' d-separated from 'A' given '{'D', 'B'}'? False
#
# Is 'E' reachable from 'A' given '{'D', 'B'}'? True
# Is 'E' d-separated from 'A' given '{'D', 'B'}'? False
#
# Is 'F' reachable from 'A' given '{'D', 'C'}'? True
# Is 'F' d-separated from 'A' given '{'D', 'C'}'? False
#
# Is 'E' reachable from 'A' given '{'D', 'C'}'? True
# Is 'E' d-separated from 'A' given '{'D', 'C'}'? False
#
# Is 'B' reachable from 'A' given '{'D', 'C'}'? True
# Is 'B' d-separated from 'A' given '{'D', 'C'}'? False
#
# Is 'D' reachable from 'A' given '{'F', 'E'}'? True
# Is 'D' d-separated from 'A' given '{'F', 'E'}'? False
#
# Is 'C' reachable from 'A' given '{'F', 'E'}'? True
# Is 'C' d-separated from 'A' given '{'F', 'E'}'? False
#
# Is 'B' reachable from 'A' given '{'F', 'E'}'? False
# Is 'B' d-separated from 'A' given '{'F', 'E'}'? True
#
# Is 'F' reachable from 'A' given '{'E', 'B'}'? False
# Is 'F' d-separated from 'A' given '{'E', 'B'}'? True
#
# Is 'D' reachable from 'A' given '{'E', 'B'}'? True
# Is 'D' d-separated from 'A' given '{'E', 'B'}'? False
#
# Is 'C' reachable from 'A' given '{'E', 'B'}'? True
# Is 'C' d-separated from 'A' given '{'E', 'B'}'? False
#
# Is 'F' reachable from 'A' given '{'C', 'E'}'? True
# Is 'F' d-separated from 'A' given '{'C', 'E'}'? False
#
# Is 'D' reachable from 'A' given '{'C', 'E'}'? False
# Is 'D' d-separated from 'A' given '{'C', 'E'}'? True
#
# Is 'B' reachable from 'A' given '{'C', 'E'}'? True
# Is 'B' d-separated from 'A' given '{'C', 'E'}'? False
#
# Is 'D' reachable from 'A' given '{'F', 'B'}'? True
# Is 'D' d-separated from 'A' given '{'F', 'B'}'? False
#
# Is 'C' reachable from 'A' given '{'F', 'B'}'? True
# Is 'C' d-separated from 'A' given '{'F', 'B'}'? False
#
# Is 'E' reachable from 'A' given '{'F', 'B'}'? True
# Is 'E' d-separated from 'A' given '{'F', 'B'}'? False
#
# Is 'D' reachable from 'A' given '{'F', 'C'}'? False
# Is 'D' d-separated from 'A' given '{'F', 'C'}'? True
#
# Is 'E' reachable from 'A' given '{'F', 'C'}'? True
# Is 'E' d-separated from 'A' given '{'F', 'C'}'? False
#
# Is 'B' reachable from 'A' given '{'F', 'C'}'? True
# Is 'B' d-separated from 'A' given '{'F', 'C'}'? False
#
# Is 'F' reachable from 'A' given '{'C', 'B'}'? False
# Is 'F' d-separated from 'A' given '{'C', 'B'}'? True
#
# Is 'D' reachable from 'A' given '{'C', 'B'}'? False
# Is 'D' d-separated from 'A' given '{'C', 'B'}'? True
#
# Is 'E' reachable from 'A' given '{'C', 'B'}'? True
# Is 'E' d-separated from 'A' given '{'C', 'B'}'? False
#
# Is 'C' reachable from 'A' given '{'F', 'D', 'E'}'? True
# Is 'C' d-separated from 'A' given '{'F', 'D', 'E'}'? False
#
# Is 'B' reachable from 'A' given '{'F', 'D', 'E'}'? True
# Is 'B' d-separated from 'A' given '{'F', 'D', 'E'}'? False
#
# Is 'F' reachable from 'A' given '{'D', 'E', 'B'}'? False
# Is 'F' d-separated from 'A' given '{'D', 'E', 'B'}'? True
#
# Is 'C' reachable from 'A' given '{'D', 'E', 'B'}'? True
# Is 'C' d-separated from 'A' given '{'D', 'E', 'B'}'? False
#
# Is 'F' reachable from 'A' given '{'D', 'C', 'E'}'? True
# Is 'F' d-separated from 'A' given '{'D', 'C', 'E'}'? False
#
# Is 'B' reachable from 'A' given '{'D', 'C', 'E'}'? True
# Is 'B' d-separated from 'A' given '{'D', 'C', 'E'}'? False
#
# Is 'C' reachable from 'A' given '{'F', 'D', 'B'}'? True
# Is 'C' d-separated from 'A' given '{'F', 'D', 'B'}'? False
#
# Is 'E' reachable from 'A' given '{'F', 'D', 'B'}'? True
# Is 'E' d-separated from 'A' given '{'F', 'D', 'B'}'? False
#
# Is 'E' reachable from 'A' given '{'F', 'D', 'C'}'? True
# Is 'E' d-separated from 'A' given '{'F', 'D', 'C'}'? False
#
# Is 'B' reachable from 'A' given '{'F', 'D', 'C'}'? True
# Is 'B' d-separated from 'A' given '{'F', 'D', 'C'}'? False
#
# Is 'F' reachable from 'A' given '{'D', 'C', 'B'}'? False
# Is 'F' d-separated from 'A' given '{'D', 'C', 'B'}'? True
#
# Is 'E' reachable from 'A' given '{'D', 'C', 'B'}'? True
# Is 'E' d-separated from 'A' given '{'D', 'C', 'B'}'? False
#
# Is 'D' reachable from 'A' given '{'F', 'E', 'B'}'? True
# Is 'D' d-separated from 'A' given '{'F', 'E', 'B'}'? False
#
# Is 'C' reachable from 'A' given '{'F', 'E', 'B'}'? True
# Is 'C' d-separated from 'A' given '{'F', 'E', 'B'}'? False
#
# Is 'D' reachable from 'A' given '{'F', 'C', 'E'}'? False
# Is 'D' d-separated from 'A' given '{'F', 'C', 'E'}'? True
#
# Is 'B' reachable from 'A' given '{'F', 'C', 'E'}'? True
# Is 'B' d-separated from 'A' given '{'F', 'C', 'E'}'? False
#
# Is 'F' reachable from 'A' given '{'C', 'E', 'B'}'? False
# Is 'F' d-separated from 'A' given '{'C', 'E', 'B'}'? True
#
# Is 'D' reachable from 'A' given '{'C', 'E', 'B'}'? False
# Is 'D' d-separated from 'A' given '{'C', 'E', 'B'}'? True
#
# Is 'D' reachable from 'A' given '{'F', 'C', 'B'}'? False
# Is 'D' d-separated from 'A' given '{'F', 'C', 'B'}'? True
#
# Is 'E' reachable from 'A' given '{'F', 'C', 'B'}'? True
# Is 'E' d-separated from 'A' given '{'F', 'C', 'B'}'? False
#
# Is 'C' reachable from 'A' given '{'F', 'D', 'E', 'B'}'? True
# Is 'C' d-separated from 'A' given '{'F', 'D', 'E', 'B'}'? False
#
# Is 'B' reachable from 'A' given '{'F', 'D', 'C', 'E'}'? True
# Is 'B' d-separated from 'A' given '{'F', 'D', 'C', 'E'}'? False
#
# Is 'F' reachable from 'A' given '{'D', 'C', 'E', 'B'}'? False
# Is 'F' d-separated from 'A' given '{'D', 'C', 'E', 'B'}'? True
#
# Is 'E' reachable from 'A' given '{'F', 'D', 'C', 'B'}'? True
# Is 'E' d-separated from 'A' given '{'F', 'D', 'C', 'B'}'? False
#
# Is 'D' reachable from 'A' given '{'F', 'C', 'E', 'B'}'? False
# Is 'D' d-separated from 'A' given '{'F', 'C', 'E', 'B'}'? True
#
# Is 'D' reachable from 'E' given 'set()'? True
# Is 'D' d-separated from 'E' given 'set()'? False
#
# Is 'A' reachable from 'E' given 'set()'? True
# Is 'A' d-separated from 'E' given 'set()'? False
#
# Is 'B' reachable from 'E' given 'set()'? False
# Is 'B' d-separated from 'E' given 'set()'? True
#
# Is 'F' reachable from 'E' given 'set()'? False
# Is 'F' d-separated from 'E' given 'set()'? True
#
# Is 'C' reachable from 'E' given 'set()'? True
# Is 'C' d-separated from 'E' given 'set()'? False
#
# Is 'F' reachable from 'E' given '{'D'}'? True
# Is 'F' d-separated from 'E' given '{'D'}'? False
#
# Is 'A' reachable from 'E' given '{'D'}'? True
# Is 'A' d-separated from 'E' given '{'D'}'? False
#
# Is 'C' reachable from 'E' given '{'D'}'? True
# Is 'C' d-separated from 'E' given '{'D'}'? False
#
# Is 'B' reachable from 'E' given '{'D'}'? True
# Is 'B' d-separated from 'E' given '{'D'}'? False
#
# Is 'F' reachable from 'E' given '{'A'}'? False
# Is 'F' d-separated from 'E' given '{'A'}'? True
#
# Is 'D' reachable from 'E' given '{'A'}'? False
# Is 'D' d-separated from 'E' given '{'A'}'? True
#
# Is 'C' reachable from 'E' given '{'A'}'? False
# Is 'C' d-separated from 'E' given '{'A'}'? True
#
# Is 'B' reachable from 'E' given '{'A'}'? False
# Is 'B' d-separated from 'E' given '{'A'}'? True
#
# Is 'D' reachable from 'E' given '{'F'}'? True
# Is 'D' d-separated from 'E' given '{'F'}'? False
#
# Is 'A' reachable from 'E' given '{'F'}'? True
# Is 'A' d-separated from 'E' given '{'F'}'? False
#
# Is 'C' reachable from 'E' given '{'F'}'? True
# Is 'C' d-separated from 'E' given '{'F'}'? False
#
# Is 'B' reachable from 'E' given '{'F'}'? False
# Is 'B' d-separated from 'E' given '{'F'}'? True
#
# Is 'F' reachable from 'E' given '{'B'}'? False
# Is 'F' d-separated from 'E' given '{'B'}'? True
#
# Is 'D' reachable from 'E' given '{'B'}'? True
# Is 'D' d-separated from 'E' given '{'B'}'? False
#
# Is 'A' reachable from 'E' given '{'B'}'? True
# Is 'A' d-separated from 'E' given '{'B'}'? False
#
# Is 'C' reachable from 'E' given '{'B'}'? True
# Is 'C' d-separated from 'E' given '{'B'}'? False
#
# Is 'F' reachable from 'E' given '{'C'}'? True
# Is 'F' d-separated from 'E' given '{'C'}'? False
#
# Is 'D' reachable from 'E' given '{'C'}'? False
# Is 'D' d-separated from 'E' given '{'C'}'? True
#
# Is 'A' reachable from 'E' given '{'C'}'? True
# Is 'A' d-separated from 'E' given '{'C'}'? False
#
# Is 'B' reachable from 'E' given '{'C'}'? True
# Is 'B' d-separated from 'E' given '{'C'}'? False
#
# Is 'F' reachable from 'E' given '{'D', 'A'}'? False
# Is 'F' d-separated from 'E' given '{'D', 'A'}'? True
#
# Is 'C' reachable from 'E' given '{'D', 'A'}'? False
# Is 'C' d-separated from 'E' given '{'D', 'A'}'? True
#
# Is 'B' reachable from 'E' given '{'D', 'A'}'? False
# Is 'B' d-separated from 'E' given '{'D', 'A'}'? True
#
# Is 'A' reachable from 'E' given '{'F', 'D'}'? True
# Is 'A' d-separated from 'E' given '{'F', 'D'}'? False
#
# Is 'C' reachable from 'E' given '{'F', 'D'}'? True
# Is 'C' d-separated from 'E' given '{'F', 'D'}'? False
#
# Is 'B' reachable from 'E' given '{'F', 'D'}'? True
# Is 'B' d-separated from 'E' given '{'F', 'D'}'? False
#
# Is 'F' reachable from 'E' given '{'D', 'B'}'? False
# Is 'F' d-separated from 'E' given '{'D', 'B'}'? True
#
# Is 'A' reachable from 'E' given '{'D', 'B'}'? True
# Is 'A' d-separated from 'E' given '{'D', 'B'}'? False
#
# Is 'C' reachable from 'E' given '{'D', 'B'}'? True
# Is 'C' d-separated from 'E' given '{'D', 'B'}'? False
#
# Is 'F' reachable from 'E' given '{'D', 'C'}'? True
# Is 'F' d-separated from 'E' given '{'D', 'C'}'? False
#
# Is 'A' reachable from 'E' given '{'D', 'C'}'? True
# Is 'A' d-separated from 'E' given '{'D', 'C'}'? False
#
# Is 'B' reachable from 'E' given '{'D', 'C'}'? True
# Is 'B' d-separated from 'E' given '{'D', 'C'}'? False
#
# Is 'D' reachable from 'E' given '{'F', 'A'}'? False
# Is 'D' d-separated from 'E' given '{'F', 'A'}'? True
#
# Is 'C' reachable from 'E' given '{'F', 'A'}'? False
# Is 'C' d-separated from 'E' given '{'F', 'A'}'? True
#
# Is 'B' reachable from 'E' given '{'F', 'A'}'? False
# Is 'B' d-separated from 'E' given '{'F', 'A'}'? True
#
# Is 'F' reachable from 'E' given '{'A', 'B'}'? False
# Is 'F' d-separated from 'E' given '{'A', 'B'}'? True
#
# Is 'D' reachable from 'E' given '{'A', 'B'}'? False
# Is 'D' d-separated from 'E' given '{'A', 'B'}'? True
#
# Is 'C' reachable from 'E' given '{'A', 'B'}'? False
# Is 'C' d-separated from 'E' given '{'A', 'B'}'? True
#
# Is 'F' reachable from 'E' given '{'A', 'C'}'? False
# Is 'F' d-separated from 'E' given '{'A', 'C'}'? True
#
# Is 'D' reachable from 'E' given '{'A', 'C'}'? False
# Is 'D' d-separated from 'E' given '{'A', 'C'}'? True
#
# Is 'B' reachable from 'E' given '{'A', 'C'}'? False
# Is 'B' d-separated from 'E' given '{'A', 'C'}'? True
#
# Is 'D' reachable from 'E' given '{'F', 'B'}'? True
# Is 'D' d-separated from 'E' given '{'F', 'B'}'? False
#
# Is 'A' reachable from 'E' given '{'F', 'B'}'? True
# Is 'A' d-separated from 'E' given '{'F', 'B'}'? False
#
# Is 'C' reachable from 'E' given '{'F', 'B'}'? True
# Is 'C' d-separated from 'E' given '{'F', 'B'}'? False
#
# Is 'D' reachable from 'E' given '{'F', 'C'}'? False
# Is 'D' d-separated from 'E' given '{'F', 'C'}'? True
#
# Is 'A' reachable from 'E' given '{'F', 'C'}'? True
# Is 'A' d-separated from 'E' given '{'F', 'C'}'? False
#
# Is 'B' reachable from 'E' given '{'F', 'C'}'? True
# Is 'B' d-separated from 'E' given '{'F', 'C'}'? False
#
# Is 'F' reachable from 'E' given '{'C', 'B'}'? False
# Is 'F' d-separated from 'E' given '{'C', 'B'}'? True
#
# Is 'D' reachable from 'E' given '{'C', 'B'}'? False
# Is 'D' d-separated from 'E' given '{'C', 'B'}'? True
#
# Is 'A' reachable from 'E' given '{'C', 'B'}'? True
# Is 'A' d-separated from 'E' given '{'C', 'B'}'? False
#
# Is 'C' reachable from 'E' given '{'F', 'D', 'A'}'? False
# Is 'C' d-separated from 'E' given '{'F', 'D', 'A'}'? True
#
# Is 'B' reachable from 'E' given '{'F', 'D', 'A'}'? False
# Is 'B' d-separated from 'E' given '{'F', 'D', 'A'}'? True
#
# Is 'F' reachable from 'E' given '{'D', 'A', 'B'}'? False
# Is 'F' d-separated from 'E' given '{'D', 'A', 'B'}'? True
#
# Is 'C' reachable from 'E' given '{'D', 'A', 'B'}'? False
# Is 'C' d-separated from 'E' given '{'D', 'A', 'B'}'? True
#
# Is 'F' reachable from 'E' given '{'D', 'A', 'C'}'? False
# Is 'F' d-separated from 'E' given '{'D', 'A', 'C'}'? True
#
# Is 'B' reachable from 'E' given '{'D', 'A', 'C'}'? False
# Is 'B' d-separated from 'E' given '{'D', 'A', 'C'}'? True
#
# Is 'A' reachable from 'E' given '{'F', 'D', 'B'}'? True
# Is 'A' d-separated from 'E' given '{'F', 'D', 'B'}'? False
#
# Is 'C' reachable from 'E' given '{'F', 'D', 'B'}'? True
# Is 'C' d-separated from 'E' given '{'F', 'D', 'B'}'? False
#
# Is 'A' reachable from 'E' given '{'F', 'D', 'C'}'? True
# Is 'A' d-separated from 'E' given '{'F', 'D', 'C'}'? False
#
# Is 'B' reachable from 'E' given '{'F', 'D', 'C'}'? True
# Is 'B' d-separated from 'E' given '{'F', 'D', 'C'}'? False
#
# Is 'F' reachable from 'E' given '{'D', 'C', 'B'}'? False
# Is 'F' d-separated from 'E' given '{'D', 'C', 'B'}'? True
#
# Is 'A' reachable from 'E' given '{'D', 'C', 'B'}'? True
# Is 'A' d-separated from 'E' given '{'D', 'C', 'B'}'? False
#
# Is 'D' reachable from 'E' given '{'F', 'A', 'B'}'? False
# Is 'D' d-separated from 'E' given '{'F', 'A', 'B'}'? True
#
# Is 'C' reachable from 'E' given '{'F', 'A', 'B'}'? False
# Is 'C' d-separated from 'E' given '{'F', 'A', 'B'}'? True
#
# Is 'D' reachable from 'E' given '{'F', 'A', 'C'}'? False
# Is 'D' d-separated from 'E' given '{'F', 'A', 'C'}'? True
#
# Is 'B' reachable from 'E' given '{'F', 'A', 'C'}'? False
# Is 'B' d-separated from 'E' given '{'F', 'A', 'C'}'? True
#
# Is 'F' reachable from 'E' given '{'A', 'C', 'B'}'? False
# Is 'F' d-separated from 'E' given '{'A', 'C', 'B'}'? True
#
# Is 'D' reachable from 'E' given '{'A', 'C', 'B'}'? False
# Is 'D' d-separated from 'E' given '{'A', 'C', 'B'}'? True
#
# Is 'D' reachable from 'E' given '{'F', 'C', 'B'}'? False
# Is 'D' d-separated from 'E' given '{'F', 'C', 'B'}'? True
#
# Is 'A' reachable from 'E' given '{'F', 'C', 'B'}'? True
# Is 'A' d-separated from 'E' given '{'F', 'C', 'B'}'? False
#
# Is 'C' reachable from 'E' given '{'F', 'D', 'A', 'B'}'? False
# Is 'C' d-separated from 'E' given '{'F', 'D', 'A', 'B'}'? True
#
# Is 'B' reachable from 'E' given '{'F', 'D', 'A', 'C'}'? False
# Is 'B' d-separated from 'E' given '{'F', 'D', 'A', 'C'}'? True
#
# Is 'F' reachable from 'E' given '{'D', 'A', 'C', 'B'}'? False
# Is 'F' d-separated from 'E' given '{'D', 'A', 'C', 'B'}'? True
#
# Is 'A' reachable from 'E' given '{'F', 'D', 'C', 'B'}'? True
# Is 'A' d-separated from 'E' given '{'F', 'D', 'C', 'B'}'? False
#
# Is 'D' reachable from 'E' given '{'F', 'A', 'C', 'B'}'? False
# Is 'D' d-separated from 'E' given '{'F', 'A', 'C', 'B'}'? True
#
# Is 'D' reachable from 'F' given 'set()'? True
# Is 'D' d-separated from 'F' given 'set()'? False
#
# Is 'A' reachable from 'F' given 'set()'? False
# Is 'A' d-separated from 'F' given 'set()'? True
#
# Is 'E' reachable from 'F' given 'set()'? False
# Is 'E' d-separated from 'F' given 'set()'? True
#
# Is 'B' reachable from 'F' given 'set()'? True
# Is 'B' d-separated from 'F' given 'set()'? False
#
# Is 'C' reachable from 'F' given 'set()'? True
# Is 'C' d-separated from 'F' given 'set()'? False
#
# Is 'A' reachable from 'F' given '{'D'}'? True
# Is 'A' d-separated from 'F' given '{'D'}'? False
#
# Is 'C' reachable from 'F' given '{'D'}'? True
# Is 'C' d-separated from 'F' given '{'D'}'? False
#
# Is 'E' reachable from 'F' given '{'D'}'? True
# Is 'E' d-separated from 'F' given '{'D'}'? False
#
# Is 'B' reachable from 'F' given '{'D'}'? True
# Is 'B' d-separated from 'F' given '{'D'}'? False
#
# Is 'D' reachable from 'F' given '{'A'}'? True
# Is 'D' d-separated from 'F' given '{'A'}'? False
#
# Is 'C' reachable from 'F' given '{'A'}'? True
# Is 'C' d-separated from 'F' given '{'A'}'? False
#
# Is 'E' reachable from 'F' given '{'A'}'? False
# Is 'E' d-separated from 'F' given '{'A'}'? True
#
# Is 'B' reachable from 'F' given '{'A'}'? True
# Is 'B' d-separated from 'F' given '{'A'}'? False
#
# Is 'D' reachable from 'F' given '{'E'}'? True
# Is 'D' d-separated from 'F' given '{'E'}'? False
#
# Is 'A' reachable from 'F' given '{'E'}'? False
# Is 'A' d-separated from 'F' given '{'E'}'? True
#
# Is 'C' reachable from 'F' given '{'E'}'? True
# Is 'C' d-separated from 'F' given '{'E'}'? False
#
# Is 'B' reachable from 'F' given '{'E'}'? True
# Is 'B' d-separated from 'F' given '{'E'}'? False
#
# Is 'D' reachable from 'F' given '{'B'}'? False
# Is 'D' d-separated from 'F' given '{'B'}'? True
#
# Is 'A' reachable from 'F' given '{'B'}'? False
# Is 'A' d-separated from 'F' given '{'B'}'? True
#
# Is 'C' reachable from 'F' given '{'B'}'? False
# Is 'C' d-separated from 'F' given '{'B'}'? True
#
# Is 'E' reachable from 'F' given '{'B'}'? False
# Is 'E' d-separated from 'F' given '{'B'}'? True
#
# Is 'D' reachable from 'F' given '{'C'}'? False
# Is 'D' d-separated from 'F' given '{'C'}'? True
#
# Is 'A' reachable from 'F' given '{'C'}'? True
# Is 'A' d-separated from 'F' given '{'C'}'? False
#
# Is 'E' reachable from 'F' given '{'C'}'? True
# Is 'E' d-separated from 'F' given '{'C'}'? False
#
# Is 'B' reachable from 'F' given '{'C'}'? True
# Is 'B' d-separated from 'F' given '{'C'}'? False
#
# Is 'C' reachable from 'F' given '{'D', 'A'}'? True
# Is 'C' d-separated from 'F' given '{'D', 'A'}'? False
#
# Is 'E' reachable from 'F' given '{'D', 'A'}'? False
# Is 'E' d-separated from 'F' given '{'D', 'A'}'? True
#
# Is 'B' reachable from 'F' given '{'D', 'A'}'? True
# Is 'B' d-separated from 'F' given '{'D', 'A'}'? False
#
# Is 'A' reachable from 'F' given '{'D', 'E'}'? True
# Is 'A' d-separated from 'F' given '{'D', 'E'}'? False
#
# Is 'C' reachable from 'F' given '{'D', 'E'}'? True
# Is 'C' d-separated from 'F' given '{'D', 'E'}'? False
#
# Is 'B' reachable from 'F' given '{'D', 'E'}'? True
# Is 'B' d-separated from 'F' given '{'D', 'E'}'? False
#
# Is 'A' reachable from 'F' given '{'D', 'B'}'? False
# Is 'A' d-separated from 'F' given '{'D', 'B'}'? True
#
# Is 'C' reachable from 'F' given '{'D', 'B'}'? False
# Is 'C' d-separated from 'F' given '{'D', 'B'}'? True
#
# Is 'E' reachable from 'F' given '{'D', 'B'}'? False
# Is 'E' d-separated from 'F' given '{'D', 'B'}'? True
#
# Is 'A' reachable from 'F' given '{'D', 'C'}'? True
# Is 'A' d-separated from 'F' given '{'D', 'C'}'? False
#
# Is 'E' reachable from 'F' given '{'D', 'C'}'? True
# Is 'E' d-separated from 'F' given '{'D', 'C'}'? False
#
# Is 'B' reachable from 'F' given '{'D', 'C'}'? True
# Is 'B' d-separated from 'F' given '{'D', 'C'}'? False
#
# Is 'D' reachable from 'F' given '{'A', 'E'}'? True
# Is 'D' d-separated from 'F' given '{'A', 'E'}'? False
#
# Is 'C' reachable from 'F' given '{'A', 'E'}'? True
# Is 'C' d-separated from 'F' given '{'A', 'E'}'? False
#
# Is 'B' reachable from 'F' given '{'A', 'E'}'? True
# Is 'B' d-separated from 'F' given '{'A', 'E'}'? False
#
# Is 'D' reachable from 'F' given '{'A', 'B'}'? False
# Is 'D' d-separated from 'F' given '{'A', 'B'}'? True
#
# Is 'C' reachable from 'F' given '{'A', 'B'}'? False
# Is 'C' d-separated from 'F' given '{'A', 'B'}'? True
#
# Is 'E' reachable from 'F' given '{'A', 'B'}'? False
# Is 'E' d-separated from 'F' given '{'A', 'B'}'? True
#
# Is 'D' reachable from 'F' given '{'A', 'C'}'? False
# Is 'D' d-separated from 'F' given '{'A', 'C'}'? True
#
# Is 'E' reachable from 'F' given '{'A', 'C'}'? False
# Is 'E' d-separated from 'F' given '{'A', 'C'}'? True
#
# Is 'B' reachable from 'F' given '{'A', 'C'}'? True
# Is 'B' d-separated from 'F' given '{'A', 'C'}'? False
#
# Is 'D' reachable from 'F' given '{'E', 'B'}'? False
# Is 'D' d-separated from 'F' given '{'E', 'B'}'? True
#
# Is 'A' reachable from 'F' given '{'E', 'B'}'? False
# Is 'A' d-separated from 'F' given '{'E', 'B'}'? True
#
# Is 'C' reachable from 'F' given '{'E', 'B'}'? False
# Is 'C' d-separated from 'F' given '{'E', 'B'}'? True
#
# Is 'D' reachable from 'F' given '{'C', 'E'}'? False
# Is 'D' d-separated from 'F' given '{'C', 'E'}'? True
#
# Is 'A' reachable from 'F' given '{'C', 'E'}'? True
# Is 'A' d-separated from 'F' given '{'C', 'E'}'? False
#
# Is 'B' reachable from 'F' given '{'C', 'E'}'? True
# Is 'B' d-separated from 'F' given '{'C', 'E'}'? False
#
# Is 'D' reachable from 'F' given '{'C', 'B'}'? False
# Is 'D' d-separated from 'F' given '{'C', 'B'}'? True
#
# Is 'A' reachable from 'F' given '{'C', 'B'}'? False
# Is 'A' d-separated from 'F' given '{'C', 'B'}'? True
#
# Is 'E' reachable from 'F' given '{'C', 'B'}'? False
# Is 'E' d-separated from 'F' given '{'C', 'B'}'? True
#
# Is 'C' reachable from 'F' given '{'D', 'A', 'E'}'? True
# Is 'C' d-separated from 'F' given '{'D', 'A', 'E'}'? False
#
# Is 'B' reachable from 'F' given '{'D', 'A', 'E'}'? True
# Is 'B' d-separated from 'F' given '{'D', 'A', 'E'}'? False
#
# Is 'C' reachable from 'F' given '{'D', 'A', 'B'}'? False
# Is 'C' d-separated from 'F' given '{'D', 'A', 'B'}'? True
#
# Is 'E' reachable from 'F' given '{'D', 'A', 'B'}'? False
# Is 'E' d-separated from 'F' given '{'D', 'A', 'B'}'? True
#
# Is 'E' reachable from 'F' given '{'D', 'A', 'C'}'? False
# Is 'E' d-separated from 'F' given '{'D', 'A', 'C'}'? True
#
# Is 'B' reachable from 'F' given '{'D', 'A', 'C'}'? True
# Is 'B' d-separated from 'F' given '{'D', 'A', 'C'}'? False
#
# Is 'A' reachable from 'F' given '{'D', 'E', 'B'}'? False
# Is 'A' d-separated from 'F' given '{'D', 'E', 'B'}'? True
#
# Is 'C' reachable from 'F' given '{'D', 'E', 'B'}'? False
# Is 'C' d-separated from 'F' given '{'D', 'E', 'B'}'? True
#
# Is 'A' reachable from 'F' given '{'D', 'C', 'E'}'? True
# Is 'A' d-separated from 'F' given '{'D', 'C', 'E'}'? False
#
# Is 'B' reachable from 'F' given '{'D', 'C', 'E'}'? True
# Is 'B' d-separated from 'F' given '{'D', 'C', 'E'}'? False
#
# Is 'A' reachable from 'F' given '{'D', 'C', 'B'}'? False
# Is 'A' d-separated from 'F' given '{'D', 'C', 'B'}'? True
#
# Is 'E' reachable from 'F' given '{'D', 'C', 'B'}'? False
# Is 'E' d-separated from 'F' given '{'D', 'C', 'B'}'? True
#
# Is 'D' reachable from 'F' given '{'A', 'E', 'B'}'? False
# Is 'D' d-separated from 'F' given '{'A', 'E', 'B'}'? True
#
# Is 'C' reachable from 'F' given '{'A', 'E', 'B'}'? False
# Is 'C' d-separated from 'F' given '{'A', 'E', 'B'}'? True
#
# Is 'D' reachable from 'F' given '{'A', 'C', 'E'}'? False
# Is 'D' d-separated from 'F' given '{'A', 'C', 'E'}'? True
#
# Is 'B' reachable from 'F' given '{'A', 'C', 'E'}'? True
# Is 'B' d-separated from 'F' given '{'A', 'C', 'E'}'? False
#
# Is 'D' reachable from 'F' given '{'A', 'C', 'B'}'? False
# Is 'D' d-separated from 'F' given '{'A', 'C', 'B'}'? True
#
# Is 'E' reachable from 'F' given '{'A', 'C', 'B'}'? False
# Is 'E' d-separated from 'F' given '{'A', 'C', 'B'}'? True
#
# Is 'D' reachable from 'F' given '{'C', 'E', 'B'}'? False
# Is 'D' d-separated from 'F' given '{'C', 'E', 'B'}'? True
#
# Is 'A' reachable from 'F' given '{'C', 'E', 'B'}'? False
# Is 'A' d-separated from 'F' given '{'C', 'E', 'B'}'? True
#
# Is 'C' reachable from 'F' given '{'D', 'A', 'E', 'B'}'? False
# Is 'C' d-separated from 'F' given '{'D', 'A', 'E', 'B'}'? True
#
# Is 'B' reachable from 'F' given '{'D', 'A', 'C', 'E'}'? True
# Is 'B' d-separated from 'F' given '{'D', 'A', 'C', 'E'}'? False
#
# Is 'E' reachable from 'F' given '{'D', 'A', 'C', 'B'}'? False
# Is 'E' d-separated from 'F' given '{'D', 'A', 'C', 'B'}'? True
#
# Is 'A' reachable from 'F' given '{'D', 'C', 'E', 'B'}'? False
# Is 'A' d-separated from 'F' given '{'D', 'C', 'E', 'B'}'? True
#
# Is 'D' reachable from 'F' given '{'A', 'C', 'E', 'B'}'? False
# Is 'D' d-separated from 'F' given '{'A', 'C', 'E', 'B'}'? True
#
# Is 'D' reachable from 'B' given 'set()'? True
# Is 'D' d-separated from 'B' given 'set()'? False
#
# Is 'A' reachable from 'B' given 'set()'? False
# Is 'A' d-separated from 'B' given 'set()'? True
#
# Is 'E' reachable from 'B' given 'set()'? False
# Is 'E' d-separated from 'B' given 'set()'? True
#
# Is 'F' reachable from 'B' given 'set()'? True
# Is 'F' d-separated from 'B' given 'set()'? False
#
# Is 'C' reachable from 'B' given 'set()'? True
# Is 'C' d-separated from 'B' given 'set()'? False
#
# Is 'F' reachable from 'B' given '{'D'}'? True
# Is 'F' d-separated from 'B' given '{'D'}'? False
#
# Is 'A' reachable from 'B' given '{'D'}'? True
# Is 'A' d-separated from 'B' given '{'D'}'? False
#
# Is 'C' reachable from 'B' given '{'D'}'? True
# Is 'C' d-separated from 'B' given '{'D'}'? False
#
# Is 'E' reachable from 'B' given '{'D'}'? True
# Is 'E' d-separated from 'B' given '{'D'}'? False
#
# Is 'F' reachable from 'B' given '{'A'}'? True
# Is 'F' d-separated from 'B' given '{'A'}'? False
#
# Is 'D' reachable from 'B' given '{'A'}'? True
# Is 'D' d-separated from 'B' given '{'A'}'? False
#
# Is 'C' reachable from 'B' given '{'A'}'? True
# Is 'C' d-separated from 'B' given '{'A'}'? False
#
# Is 'E' reachable from 'B' given '{'A'}'? False
# Is 'E' d-separated from 'B' given '{'A'}'? True
#
# Is 'F' reachable from 'B' given '{'E'}'? True
# Is 'F' d-separated from 'B' given '{'E'}'? False
#
# Is 'D' reachable from 'B' given '{'E'}'? True
# Is 'D' d-separated from 'B' given '{'E'}'? False
#
# Is 'A' reachable from 'B' given '{'E'}'? False
# Is 'A' d-separated from 'B' given '{'E'}'? True
#
# Is 'C' reachable from 'B' given '{'E'}'? True
# Is 'C' d-separated from 'B' given '{'E'}'? False
#
# Is 'D' reachable from 'B' given '{'F'}'? True
# Is 'D' d-separated from 'B' given '{'F'}'? False
#
# Is 'A' reachable from 'B' given '{'F'}'? False
# Is 'A' d-separated from 'B' given '{'F'}'? True
#
# Is 'C' reachable from 'B' given '{'F'}'? True
# Is 'C' d-separated from 'B' given '{'F'}'? False
#
# Is 'E' reachable from 'B' given '{'F'}'? False
# Is 'E' d-separated from 'B' given '{'F'}'? True
#
# Is 'F' reachable from 'B' given '{'C'}'? True
# Is 'F' d-separated from 'B' given '{'C'}'? False
#
# Is 'D' reachable from 'B' given '{'C'}'? False
# Is 'D' d-separated from 'B' given '{'C'}'? True
#
# Is 'A' reachable from 'B' given '{'C'}'? True
# Is 'A' d-separated from 'B' given '{'C'}'? False
#
# Is 'E' reachable from 'B' given '{'C'}'? True
# Is 'E' d-separated from 'B' given '{'C'}'? False
#
# Is 'F' reachable from 'B' given '{'D', 'A'}'? True
# Is 'F' d-separated from 'B' given '{'D', 'A'}'? False
#
# Is 'C' reachable from 'B' given '{'D', 'A'}'? True
# Is 'C' d-separated from 'B' given '{'D', 'A'}'? False
#
# Is 'E' reachable from 'B' given '{'D', 'A'}'? False
# Is 'E' d-separated from 'B' given '{'D', 'A'}'? True
#
# Is 'F' reachable from 'B' given '{'D', 'E'}'? True
# Is 'F' d-separated from 'B' given '{'D', 'E'}'? False
#
# Is 'A' reachable from 'B' given '{'D', 'E'}'? True
# Is 'A' d-separated from 'B' given '{'D', 'E'}'? False
#
# Is 'C' reachable from 'B' given '{'D', 'E'}'? True
# Is 'C' d-separated from 'B' given '{'D', 'E'}'? False
#
# Is 'A' reachable from 'B' given '{'F', 'D'}'? True
# Is 'A' d-separated from 'B' given '{'F', 'D'}'? False
#
# Is 'C' reachable from 'B' given '{'F', 'D'}'? True
# Is 'C' d-separated from 'B' given '{'F', 'D'}'? False
#
# Is 'E' reachable from 'B' given '{'F', 'D'}'? True
# Is 'E' d-separated from 'B' given '{'F', 'D'}'? False
#
# Is 'F' reachable from 'B' given '{'D', 'C'}'? True
# Is 'F' d-separated from 'B' given '{'D', 'C'}'? False
#
# Is 'A' reachable from 'B' given '{'D', 'C'}'? True
# Is 'A' d-separated from 'B' given '{'D', 'C'}'? False
#
# Is 'E' reachable from 'B' given '{'D', 'C'}'? True
# Is 'E' d-separated from 'B' given '{'D', 'C'}'? False
#
# Is 'F' reachable from 'B' given '{'A', 'E'}'? True
# Is 'F' d-separated from 'B' given '{'A', 'E'}'? False
#
# Is 'D' reachable from 'B' given '{'A', 'E'}'? True
# Is 'D' d-separated from 'B' given '{'A', 'E'}'? False
#
# Is 'C' reachable from 'B' given '{'A', 'E'}'? True
# Is 'C' d-separated from 'B' given '{'A', 'E'}'? False
#
# Is 'D' reachable from 'B' given '{'F', 'A'}'? True
# Is 'D' d-separated from 'B' given '{'F', 'A'}'? False
#
# Is 'C' reachable from 'B' given '{'F', 'A'}'? True
# Is 'C' d-separated from 'B' given '{'F', 'A'}'? False
#
# Is 'E' reachable from 'B' given '{'F', 'A'}'? False
# Is 'E' d-separated from 'B' given '{'F', 'A'}'? True
#
# Is 'F' reachable from 'B' given '{'A', 'C'}'? True
# Is 'F' d-separated from 'B' given '{'A', 'C'}'? False
#
# Is 'D' reachable from 'B' given '{'A', 'C'}'? False
# Is 'D' d-separated from 'B' given '{'A', 'C'}'? True
#
# Is 'E' reachable from 'B' given '{'A', 'C'}'? False
# Is 'E' d-separated from 'B' given '{'A', 'C'}'? True
#
# Is 'D' reachable from 'B' given '{'F', 'E'}'? True
# Is 'D' d-separated from 'B' given '{'F', 'E'}'? False
#
# Is 'A' reachable from 'B' given '{'F', 'E'}'? False
# Is 'A' d-separated from 'B' given '{'F', 'E'}'? True
#
# Is 'C' reachable from 'B' given '{'F', 'E'}'? True
# Is 'C' d-separated from 'B' given '{'F', 'E'}'? False
#
# Is 'F' reachable from 'B' given '{'C', 'E'}'? True
# Is 'F' d-separated from 'B' given '{'C', 'E'}'? False
#
# Is 'D' reachable from 'B' given '{'C', 'E'}'? False
# Is 'D' d-separated from 'B' given '{'C', 'E'}'? True
#
# Is 'A' reachable from 'B' given '{'C', 'E'}'? True
# Is 'A' d-separated from 'B' given '{'C', 'E'}'? False
#
# Is 'D' reachable from 'B' given '{'F', 'C'}'? False
# Is 'D' d-separated from 'B' given '{'F', 'C'}'? True
#
# Is 'A' reachable from 'B' given '{'F', 'C'}'? True
# Is 'A' d-separated from 'B' given '{'F', 'C'}'? False
#
# Is 'E' reachable from 'B' given '{'F', 'C'}'? True
# Is 'E' d-separated from 'B' given '{'F', 'C'}'? False
#
# Is 'F' reachable from 'B' given '{'D', 'A', 'E'}'? True
# Is 'F' d-separated from 'B' given '{'D', 'A', 'E'}'? False
#
# Is 'C' reachable from 'B' given '{'D', 'A', 'E'}'? True
# Is 'C' d-separated from 'B' given '{'D', 'A', 'E'}'? False
#
# Is 'C' reachable from 'B' given '{'F', 'D', 'A'}'? True
# Is 'C' d-separated from 'B' given '{'F', 'D', 'A'}'? False
#
# Is 'E' reachable from 'B' given '{'F', 'D', 'A'}'? False
# Is 'E' d-separated from 'B' given '{'F', 'D', 'A'}'? True
#
# Is 'F' reachable from 'B' given '{'D', 'A', 'C'}'? True
# Is 'F' d-separated from 'B' given '{'D', 'A', 'C'}'? False
#
# Is 'E' reachable from 'B' given '{'D', 'A', 'C'}'? False
# Is 'E' d-separated from 'B' given '{'D', 'A', 'C'}'? True
#
# Is 'A' reachable from 'B' given '{'F', 'D', 'E'}'? True
# Is 'A' d-separated from 'B' given '{'F', 'D', 'E'}'? False
#
# Is 'C' reachable from 'B' given '{'F', 'D', 'E'}'? True
# Is 'C' d-separated from 'B' given '{'F', 'D', 'E'}'? False
#
# Is 'F' reachable from 'B' given '{'D', 'C', 'E'}'? True
# Is 'F' d-separated from 'B' given '{'D', 'C', 'E'}'? False
#
# Is 'A' reachable from 'B' given '{'D', 'C', 'E'}'? True
# Is 'A' d-separated from 'B' given '{'D', 'C', 'E'}'? False
#
# Is 'A' reachable from 'B' given '{'F', 'D', 'C'}'? True
# Is 'A' d-separated from 'B' given '{'F', 'D', 'C'}'? False
#
# Is 'E' reachable from 'B' given '{'F', 'D', 'C'}'? True
# Is 'E' d-separated from 'B' given '{'F', 'D', 'C'}'? False
#
# Is 'D' reachable from 'B' given '{'F', 'A', 'E'}'? True
# Is 'D' d-separated from 'B' given '{'F', 'A', 'E'}'? False
#
# Is 'C' reachable from 'B' given '{'F', 'A', 'E'}'? True
# Is 'C' d-separated from 'B' given '{'F', 'A', 'E'}'? False
#
# Is 'F' reachable from 'B' given '{'A', 'C', 'E'}'? True
# Is 'F' d-separated from 'B' given '{'A', 'C', 'E'}'? False
#
# Is 'D' reachable from 'B' given '{'A', 'C', 'E'}'? False
# Is 'D' d-separated from 'B' given '{'A', 'C', 'E'}'? True
#
# Is 'D' reachable from 'B' given '{'F', 'A', 'C'}'? False
# Is 'D' d-separated from 'B' given '{'F', 'A', 'C'}'? True
#
# Is 'E' reachable from 'B' given '{'F', 'A', 'C'}'? False
# Is 'E' d-separated from 'B' given '{'F', 'A', 'C'}'? True
#
# Is 'D' reachable from 'B' given '{'F', 'C', 'E'}'? False
# Is 'D' d-separated from 'B' given '{'F', 'C', 'E'}'? True
#
# Is 'A' reachable from 'B' given '{'F', 'C', 'E'}'? True
# Is 'A' d-separated from 'B' given '{'F', 'C', 'E'}'? False
#
# Is 'C' reachable from 'B' given '{'F', 'D', 'A', 'E'}'? True
# Is 'C' d-separated from 'B' given '{'F', 'D', 'A', 'E'}'? False
#
# Is 'F' reachable from 'B' given '{'D', 'A', 'C', 'E'}'? True
# Is 'F' d-separated from 'B' given '{'D', 'A', 'C', 'E'}'? False
#
# Is 'E' reachable from 'B' given '{'F', 'D', 'A', 'C'}'? False
# Is 'E' d-separated from 'B' given '{'F', 'D', 'A', 'C'}'? True
#
# Is 'A' reachable from 'B' given '{'F', 'D', 'C', 'E'}'? True
# Is 'A' d-separated from 'B' given '{'F', 'D', 'C', 'E'}'? False
#
# Is 'D' reachable from 'B' given '{'F', 'A', 'C', 'E'}'? False
# Is 'D' d-separated from 'B' given '{'F', 'A', 'C', 'E'}'? True
#
# Is 'D' reachable from 'C' given 'set()'? True
# Is 'D' d-separated from 'C' given 'set()'? False
#
# Is 'A' reachable from 'C' given 'set()'? True
# Is 'A' d-separated from 'C' given 'set()'? False
#
# Is 'E' reachable from 'C' given 'set()'? True
# Is 'E' d-separated from 'C' given 'set()'? False
#
# Is 'B' reachable from 'C' given 'set()'? True
# Is 'B' d-separated from 'C' given 'set()'? False
#
# Is 'F' reachable from 'C' given 'set()'? True
# Is 'F' d-separated from 'C' given 'set()'? False
#
# Is 'F' reachable from 'C' given '{'D'}'? True
# Is 'F' d-separated from 'C' given '{'D'}'? False
#
# Is 'A' reachable from 'C' given '{'D'}'? True
# Is 'A' d-separated from 'C' given '{'D'}'? False
#
# Is 'E' reachable from 'C' given '{'D'}'? True
# Is 'E' d-separated from 'C' given '{'D'}'? False
#
# Is 'B' reachable from 'C' given '{'D'}'? True
# Is 'B' d-separated from 'C' given '{'D'}'? False
#
# Is 'F' reachable from 'C' given '{'A'}'? True
# Is 'F' d-separated from 'C' given '{'A'}'? False
#
# Is 'D' reachable from 'C' given '{'A'}'? True
# Is 'D' d-separated from 'C' given '{'A'}'? False
#
# Is 'E' reachable from 'C' given '{'A'}'? False
# Is 'E' d-separated from 'C' given '{'A'}'? True
#
# Is 'B' reachable from 'C' given '{'A'}'? True
# Is 'B' d-separated from 'C' given '{'A'}'? False
#
# Is 'F' reachable from 'C' given '{'E'}'? True
# Is 'F' d-separated from 'C' given '{'E'}'? False
#
# Is 'D' reachable from 'C' given '{'E'}'? True
# Is 'D' d-separated from 'C' given '{'E'}'? False
#
# Is 'A' reachable from 'C' given '{'E'}'? True
# Is 'A' d-separated from 'C' given '{'E'}'? False
#
# Is 'B' reachable from 'C' given '{'E'}'? True
# Is 'B' d-separated from 'C' given '{'E'}'? False
#
# Is 'D' reachable from 'C' given '{'F'}'? True
# Is 'D' d-separated from 'C' given '{'F'}'? False
#
# Is 'A' reachable from 'C' given '{'F'}'? True
# Is 'A' d-separated from 'C' given '{'F'}'? False
#
# Is 'E' reachable from 'C' given '{'F'}'? True
# Is 'E' d-separated from 'C' given '{'F'}'? False
#
# Is 'B' reachable from 'C' given '{'F'}'? True
# Is 'B' d-separated from 'C' given '{'F'}'? False
#
# Is 'F' reachable from 'C' given '{'B'}'? False
# Is 'F' d-separated from 'C' given '{'B'}'? True
#
# Is 'D' reachable from 'C' given '{'B'}'? True
# Is 'D' d-separated from 'C' given '{'B'}'? False
#
# Is 'A' reachable from 'C' given '{'B'}'? True
# Is 'A' d-separated from 'C' given '{'B'}'? False
#
# Is 'E' reachable from 'C' given '{'B'}'? True
# Is 'E' d-separated from 'C' given '{'B'}'? False
#
# Is 'F' reachable from 'C' given '{'D', 'A'}'? True
# Is 'F' d-separated from 'C' given '{'D', 'A'}'? False
#
# Is 'E' reachable from 'C' given '{'D', 'A'}'? False
# Is 'E' d-separated from 'C' given '{'D', 'A'}'? True
#
# Is 'B' reachable from 'C' given '{'D', 'A'}'? True
# Is 'B' d-separated from 'C' given '{'D', 'A'}'? False
#
# Is 'F' reachable from 'C' given '{'D', 'E'}'? True
# Is 'F' d-separated from 'C' given '{'D', 'E'}'? False
#
# Is 'A' reachable from 'C' given '{'D', 'E'}'? True
# Is 'A' d-separated from 'C' given '{'D', 'E'}'? False
#
# Is 'B' reachable from 'C' given '{'D', 'E'}'? True
# Is 'B' d-separated from 'C' given '{'D', 'E'}'? False
#
# Is 'A' reachable from 'C' given '{'F', 'D'}'? True
# Is 'A' d-separated from 'C' given '{'F', 'D'}'? False
#
# Is 'E' reachable from 'C' given '{'F', 'D'}'? True
# Is 'E' d-separated from 'C' given '{'F', 'D'}'? False
#
# Is 'B' reachable from 'C' given '{'F', 'D'}'? True
# Is 'B' d-separated from 'C' given '{'F', 'D'}'? False
#
# Is 'F' reachable from 'C' given '{'D', 'B'}'? False
# Is 'F' d-separated from 'C' given '{'D', 'B'}'? True
#
# Is 'A' reachable from 'C' given '{'D', 'B'}'? True
# Is 'A' d-separated from 'C' given '{'D', 'B'}'? False
#
# Is 'E' reachable from 'C' given '{'D', 'B'}'? True
# Is 'E' d-separated from 'C' given '{'D', 'B'}'? False
#
# Is 'F' reachable from 'C' given '{'A', 'E'}'? True
# Is 'F' d-separated from 'C' given '{'A', 'E'}'? False
#
# Is 'D' reachable from 'C' given '{'A', 'E'}'? True
# Is 'D' d-separated from 'C' given '{'A', 'E'}'? False
#
# Is 'B' reachable from 'C' given '{'A', 'E'}'? True
# Is 'B' d-separated from 'C' given '{'A', 'E'}'? False
#
# Is 'D' reachable from 'C' given '{'F', 'A'}'? True
# Is 'D' d-separated from 'C' given '{'F', 'A'}'? False
#
# Is 'E' reachable from 'C' given '{'F', 'A'}'? False
# Is 'E' d-separated from 'C' given '{'F', 'A'}'? True
#
# Is 'B' reachable from 'C' given '{'F', 'A'}'? True
# Is 'B' d-separated from 'C' given '{'F', 'A'}'? False
#
# Is 'F' reachable from 'C' given '{'A', 'B'}'? False
# Is 'F' d-separated from 'C' given '{'A', 'B'}'? True
#
# Is 'D' reachable from 'C' given '{'A', 'B'}'? True
# Is 'D' d-separated from 'C' given '{'A', 'B'}'? False
#
# Is 'E' reachable from 'C' given '{'A', 'B'}'? False
# Is 'E' d-separated from 'C' given '{'A', 'B'}'? True
#
# Is 'D' reachable from 'C' given '{'F', 'E'}'? True
# Is 'D' d-separated from 'C' given '{'F', 'E'}'? False
#
# Is 'A' reachable from 'C' given '{'F', 'E'}'? True
# Is 'A' d-separated from 'C' given '{'F', 'E'}'? False
#
# Is 'B' reachable from 'C' given '{'F', 'E'}'? True
# Is 'B' d-separated from 'C' given '{'F', 'E'}'? False
#
# Is 'F' reachable from 'C' given '{'E', 'B'}'? False
# Is 'F' d-separated from 'C' given '{'E', 'B'}'? True
#
# Is 'D' reachable from 'C' given '{'E', 'B'}'? True
# Is 'D' d-separated from 'C' given '{'E', 'B'}'? False
#
# Is 'A' reachable from 'C' given '{'E', 'B'}'? True
# Is 'A' d-separated from 'C' given '{'E', 'B'}'? False
#
# Is 'D' reachable from 'C' given '{'F', 'B'}'? True
# Is 'D' d-separated from 'C' given '{'F', 'B'}'? False
#
# Is 'A' reachable from 'C' given '{'F', 'B'}'? True
# Is 'A' d-separated from 'C' given '{'F', 'B'}'? False
#
# Is 'E' reachable from 'C' given '{'F', 'B'}'? True
# Is 'E' d-separated from 'C' given '{'F', 'B'}'? False
#
# Is 'F' reachable from 'C' given '{'D', 'A', 'E'}'? True
# Is 'F' d-separated from 'C' given '{'D', 'A', 'E'}'? False
#
# Is 'B' reachable from 'C' given '{'D', 'A', 'E'}'? True
# Is 'B' d-separated from 'C' given '{'D', 'A', 'E'}'? False
#
# Is 'E' reachable from 'C' given '{'F', 'D', 'A'}'? False
# Is 'E' d-separated from 'C' given '{'F', 'D', 'A'}'? True
#
# Is 'B' reachable from 'C' given '{'F', 'D', 'A'}'? True
# Is 'B' d-separated from 'C' given '{'F', 'D', 'A'}'? False
#
# Is 'F' reachable from 'C' given '{'D', 'A', 'B'}'? False
# Is 'F' d-separated from 'C' given '{'D', 'A', 'B'}'? True
#
# Is 'E' reachable from 'C' given '{'D', 'A', 'B'}'? False
# Is 'E' d-separated from 'C' given '{'D', 'A', 'B'}'? True
#
# Is 'A' reachable from 'C' given '{'F', 'D', 'E'}'? True
# Is 'A' d-separated from 'C' given '{'F', 'D', 'E'}'? False
#
# Is 'B' reachable from 'C' given '{'F', 'D', 'E'}'? True
# Is 'B' d-separated from 'C' given '{'F', 'D', 'E'}'? False
#
# Is 'F' reachable from 'C' given '{'D', 'E', 'B'}'? False
# Is 'F' d-separated from 'C' given '{'D', 'E', 'B'}'? True
#
# Is 'A' reachable from 'C' given '{'D', 'E', 'B'}'? True
# Is 'A' d-separated from 'C' given '{'D', 'E', 'B'}'? False
#
# Is 'A' reachable from 'C' given '{'F', 'D', 'B'}'? True
# Is 'A' d-separated from 'C' given '{'F', 'D', 'B'}'? False
#
# Is 'E' reachable from 'C' given '{'F', 'D', 'B'}'? True
# Is 'E' d-separated from 'C' given '{'F', 'D', 'B'}'? False
#
# Is 'D' reachable from 'C' given '{'F', 'A', 'E'}'? True
# Is 'D' d-separated from 'C' given '{'F', 'A', 'E'}'? False
#
# Is 'B' reachable from 'C' given '{'F', 'A', 'E'}'? True
# Is 'B' d-separated from 'C' given '{'F', 'A', 'E'}'? False
#
# Is 'F' reachable from 'C' given '{'A', 'E', 'B'}'? False
# Is 'F' d-separated from 'C' given '{'A', 'E', 'B'}'? True
#
# Is 'D' reachable from 'C' given '{'A', 'E', 'B'}'? True
# Is 'D' d-separated from 'C' given '{'A', 'E', 'B'}'? False
#
# Is 'D' reachable from 'C' given '{'F', 'A', 'B'}'? True
# Is 'D' d-separated from 'C' given '{'F', 'A', 'B'}'? False
#
# Is 'E' reachable from 'C' given '{'F', 'A', 'B'}'? False
# Is 'E' d-separated from 'C' given '{'F', 'A', 'B'}'? True
#
# Is 'D' reachable from 'C' given '{'F', 'E', 'B'}'? True
# Is 'D' d-separated from 'C' given '{'F', 'E', 'B'}'? False
#
# Is 'A' reachable from 'C' given '{'F', 'E', 'B'}'? True
# Is 'A' d-separated from 'C' given '{'F', 'E', 'B'}'? False
#
# Is 'B' reachable from 'C' given '{'F', 'D', 'A', 'E'}'? True
# Is 'B' d-separated from 'C' given '{'F', 'D', 'A', 'E'}'? False
#
# Is 'F' reachable from 'C' given '{'D', 'A', 'E', 'B'}'? False
# Is 'F' d-separated from 'C' given '{'D', 'A', 'E', 'B'}'? True
#
# Is 'E' reachable from 'C' given '{'F', 'D', 'A', 'B'}'? False
# Is 'E' d-separated from 'C' given '{'F', 'D', 'A', 'B'}'? True
#
# Is 'A' reachable from 'C' given '{'F', 'D', 'E', 'B'}'? True
# Is 'A' d-separated from 'C' given '{'F', 'D', 'E', 'B'}'? False
#
# Is 'D' reachable from 'C' given '{'F', 'A', 'E', 'B'}'? True
# Is 'D' d-separated from 'C' given '{'F', 'A', 'E', 'B'}'? False
